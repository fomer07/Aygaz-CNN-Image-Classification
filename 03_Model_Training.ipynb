# %%
from google.colab import drive
drive.mount('/content/drive')  # Mount Google Drive
# Out:
# Mounted at /content/drive

# %%
# !git add 03_Model_Training.ipynb
# !git commit -m "03_Model_Training.ipynb added."
# !git push origin main
# Out:
# [main c8eae31] 03_Model_Training.ipynb added.
#  1 file changed, 1 insertion(+)
#  create mode 100644 03_Model_Training.ipynb
# Enumerating objects: 4, done.
# Counting objects: 100% (4/4), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 1.16 KiB | 118.00 KiB/s, done.
# Total 3 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/fomer07/Aygaz-CNN-Image-Classification.git
#    d808b74..c8eae31  main -> main
