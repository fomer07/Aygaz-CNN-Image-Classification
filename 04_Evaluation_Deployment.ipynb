# %%
from google.colab import drive
drive.mount('/content/drive')  # Mount Google Drive
# Out:
# Mounted at /content/drive

# %%
# !mv /content/drive/MyDrive/Colab\ Notebooks/04_Evaluation_Deployment.ipynb /content/drive/MyDrive/Colab\ Notebooks/Aygaz-CNN-Image-Classification

# %%
# %cd /content/drive/MyDrive/Colab\ Notebooks/Aygaz-CNN-Image-Classification
# Out:
# /content/drive/MyDrive/Colab Notebooks/Aygaz-CNN-Image-Classification

# %%
# !ls
# Out:
# 01_Environment_Setup.ipynb   03_Model_Training.ipynb	     requirements.txt
# 01_Environment_Setup.py      04_Evaluation_Deployment.ipynb
# 02_Data_Preprocessing.ipynb  README.md

# %%
# !git config user.email "omerf.ay7@gmail.com"
# !git config user.name "fomer07"

# %%
# !git add 04_Evaluation_Deployment.ipynb
# !git commit -m "04_Evaluation_Deployment.ipynb"
# !git push origin main

# %%
# !git status
